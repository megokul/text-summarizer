# %%
import os
remote = "https://dagshub.com/megokul/text-summarizer.mlflow"
remote.split(os.sep)[-2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 import os
#       2 remote = "https://dagshub.com/megokul/text-summarizer.mlflow"
# ----> 3 remote.split(os.sep)[-2]
#
# IndexError: list index out of range

# %%
remote.split(os.sep)[-2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 remote.split(os.sep)[-2]
#
# IndexError: list index out of range

# %%
import os

remote = "https://dagshub.com/megokul/text-summarizer.mlflow"
remote = remote.replace("/", os.sep)  # Replace all '/' with os.sep ('\\' on Windows)
remote
# Out:
# 'https:\\\\dagshub.com\\megokul\\text-summarizer.mlflow'

# %%
owner = remote.split(os.sep)[-2]
print(owner)  # Should print 'megokul'
# Out:
# megokul

# %%
from pathlib import Path
remote = "https://dagshub.com/megokul/text-summarizer.mlflow"
Path(remote)  # This will not work as expected because remote is a URL, not a local path
# Out:
# WindowsPath('https:/dagshub.com/megokul/text-summarizer.mlflow')

# %%
owner = remote.split(os.sep)[-2]
print(owner)  # Should print 'megokul
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 owner = remote.split(os.sep)[-2]
#       2 print(owner)  # Should print 'megokul
#
# IndexError: list index out of range
